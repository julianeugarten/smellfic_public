# %%
import pandas as pd

# %%
old = pd.read_csv('old_smells_redacted.csv', header=0)
new = pd.read_csv('new_smells_redacted.csv', header=0)

# For modernity this includes the tags: Alternate Universe - Canon Divergence'", 'Alternate Universe'": 469, "'Alternate Universe - Modern Setting'"
# For mythological times this includes the tags: References to Ancient Greek Religion & Lore, Greek Mythology - Freeform, Trojan War,

# %% [markdown]
# ## Storyworld

# %%
len(new)

# old is 1457 scents long
# new is 6471 scents long
# Out:
# 6471

# %%
old_smell_counts = old['Smell_Source'].value_counts()
old_smell_counts.head(30).plot(kind='bar', title='Most frequent Smell Sources in Mythological Time')
# Out:
# <Axes: title={'center': 'Most frequent Smell Sources in Mythological Time'}, xlabel='Smell_Source'>

# %%
new_smell_counts = new['Smell_Source'].value_counts()
new_smell_counts.head(30).plot(kind='bar', title='Most frequent Smell Sources in Contemporary Times')
# Out:
# <Axes: title={'center': 'Most frequent Smell Sources in Contemporary Times'}, xlabel='Smell_Source'>
