# %%
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud, STOPWORDS

# %%
df_all = pd.read_csv('MythFic-frames_redacted.tsv', sep='\t', header=0)

# %%
#read CSV files 

male = pd.read_csv('male_smells_redacted.csv')
female = pd.read_csv('female_smells_redacted.csv')
old = pd.read_csv("old_smells_redacted.csv")
new = pd.read_csv("new_smells_redacted.csv")

# %%
#use the desired-column from the datasets
set_male = set(male['Smell_Word'])
set_female = set(female['Smell_Word'])

# %% [markdown]
# ## Creating Wordclouds

# %%
words = ''
stopwords = set(STOPWORDS)

# in the following line you can try visualizing different dataframes and columns
tokens = df_all['Location'].dropna().astype(str).tolist()

# Converts each token into lowercase
for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()
    words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10, collocations = False).generate(words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
